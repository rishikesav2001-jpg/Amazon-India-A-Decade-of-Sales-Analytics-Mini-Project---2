# %%
import pandas as pd
import numpy as np


file_path=r'C:\Users\rishi\OneDrive\Desktop\Python projects\amazon_india_2015.csv'

df = pd.read_csv(file_path)
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\4193443328.py:7: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
#df = df.drop("Unnamed: 0", axis=1)

df.head()
# Out:
#       transaction_id  order_date         customer_id   product_id  \
# 0  TXN_2015_00000001  2015-01-25  CUST_2015_00003884  PROD_000021
# 1  TXN_2015_00000002  2015-01-05  CUST_2015_00011709  PROD_000055
# 2  TXN_2015_00000003  2015-01-24  CUST_2015_00004782  PROD_000039
# 3  TXN_2015_00000004  2015-01-28  CUST_2015_00008105  PROD_000085
# 4  TXN_2015_00000005  2015-01-31  CUST_2015_00002955  PROD_000055
#
#                            product_name     category  subcategory     brand  \
# 0          Samsung Galaxy S6 16GB Black  Electronics  Smartphones   Samsung
# 1          OnePlus OnePlus 2 16GB White  Electronics  Smartphones   OnePlus
# 2      Samsung Galaxy Note 5 64GB Black  Electronics  Smartphones   Samsung
# 3  Motorola Moto G (3rd Gen) 16GB Black  Electronics  Smartphones  Motorola
# 4          OnePlus OnePlus 2 16GB White  Electronics  Smartphones   OnePlus
#
#    original_price_inr  discount_percent  ...  is_festival_sale  \
# ...

# %% [markdown]
# ##Q1 order_date columns clean

# %%
df = pd.read_csv(file_path)

df['order_date']=pd.to_datetime(df['order_date'], format='mixed')



df.to_csv(file_path, index=False)

print(" order_date clean and file updated successfully.")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\3176102917.py:1: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#  order_date clean and file updated successfully.

# %%
df['order_date'].unique()
# Out:
# <DatetimeArray>
# ['2015-01-25 00:00:00', '2015-01-05 00:00:00', '2015-01-24 00:00:00',
#  '2015-01-28 00:00:00', '2015-01-31 00:00:00', '2015-01-04 00:00:00',
#  '2015-01-27 00:00:00', '2015-01-08 00:00:00', '2015-01-18 00:00:00',
#  '2015-01-03 00:00:00',
#  ...
#  '2015-12-13 00:00:00', '2015-12-22 00:00:00', '2015-12-23 00:00:00',
#  '2015-12-19 00:00:00', '2015-12-15 00:00:00', '2015-12-31 00:00:00',
#  '2015-12-25 00:00:00', '2015-12-29 00:00:00', '2015-12-27 00:00:00',
#  '2015-12-21 00:00:00']
# Length: 365, dtype: datetime64[us]

# %% [markdown]
# ##Q2 Original_price_inr

# %%
df = pd.read_csv(file_path)

df['original_price_inr'] = df['original_price_inr'].astype(str)

chars_to_remove = ['+', ',', '$', 'Rs', '₹', '-']

for item in chars_to_remove:
    df['original_price_inr'] = df['original_price_inr'].str.replace(item, '', regex=False)

df['original_price_inr'] = pd.to_numeric(df['original_price_inr'], errors='coerce')

df.to_csv(file_path, index=False)

print("original_price_inr cleaned successfully.")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\4265221720.py:1: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# original_price_inr cleaned successfully.

# %%
df['original_price_inr'].unique()
# Out:
# array([123614.29  ,  54731.86  ,  97644.25  ,  21947.26  , 131194.65  ,
#         86987.64  ,  32169.01  ,  40264.16  ,  88664.85  ,  73967.02  ,
#         72564.1   ,   2098.7555,  45363.47  ,  23075.71  , 114096.63  ,
#         69584.33  ,  38884.19  ,  46234.09  ,  15065.01  , 164166.84  ,
#         64917.57  ,  29534.7   ,  86477.53  ,  13721.42  , 118141.16  ,
#         86591.57  ,  23264.31  ,  94029.64  ,  17206.23  ,  37013.54  ,
#        130430.24  , 130723.61  ,  41408.67  ,  56337.89  ,  75380.48  ,
#         23161.1   ,  46680.9   ,  43572.75  ,  19375.09  ,   3896.99  ,
#         20006.12  ,  30990.65  ,  96543.62  ,  22683.69  , 102649.14  ,
#        107387.37  ,  67444.91  ,  24762.02  ,  17790.72  ,  47979.    ,
#         24448.87  , 102741.22  ,  51356.92  ,  33199.84  ,   9753.11  ,
#         88872.68  ,  72369.63  , 126454.    ,  24762.    ,  78047.8   ,
#         60643.25  , 145589.8   ,  21212.    ,  40438.41  ,  12984.58  ,
# ...

# %% [markdown]
# ##Q3 customer_rating columns clean

# %%
df = pd.read_csv(file_path)

chars2_to_remove=['stars']
cols_to_clean2=['customer_rating']
for item in chars2_to_remove:
    for cols in cols_to_clean2:
        df[cols]=df[cols].astype(str).str.replace(item,'', regex=False)

df['customer_rating'] = df['customer_rating'].astype(str).str.split('/').str[0]

df.to_csv(file_path, index=False)

print(" customer_rating clean and file updated successfully.")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\3736996782.py:1: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#  customer_rating clean and file updated successfully.

# %% [markdown]
# ##Q4 customer_city

# %%
df = pd.read_csv(file_path)

city_map = {
    'ahmedabad': 'Ahmedabad',
    'aligarh': 'Aligarh',
    'allahabad': 'Allahabad',
    'bangalore': 'Bengaluru',
    'banglore': 'Bengaluru',
    'bengalore': 'Bengaluru',
    'bengaluru': 'Bengaluru',
    'bhubaneswar': 'Bhubaneswar',
    'bombay': 'Mumbai',
    'calcutta': 'Kolkata',
    'chandigarh': 'Chandigarh',
    'chenai': 'Chennai',
    'chennai': 'Chennai',
    'coimbatore': 'Coimbatore',
    'customer_city': 'Unknown',
    'delhi': 'Delhi',
    'delhi ncr': 'Delhi',
    'new delhi': 'Delhi',
    'gorakhpur': 'Gorakhpur',
    'hyderabad': 'Hyderabad',
    'indore': 'Indore',
    'jaipur': 'Jaipur',
    'kanpur': 'Kanpur',
    'kochi': 'Kochi',
    'kolkata': 'Kolkata',
    'lucknow': 'Lucknow',
    'ludhiana': 'Ludhiana',
    'madras': 'Chennai',
    'meerut': 'Meerut',
    'moradabad': 'Moradabad',
    'mumba': 'Mumbai',
    'mumbai': 'Mumbai',
    'nagpur': 'Nagpur',
    'patna': 'Patna',
    'pune': 'Pune',
    'saharanpur': 'Saharanpur',
    'surat': 'Surat',
    'vadodara': 'Vadodara',
    'varanasi': 'Varanasi',
    'visakhapatnam': 'Visakhapatnam'
}

df['customer_city'] = df['customer_city'].str.lower().map(city_map)

df.to_csv(file_path, index=False)

print(" customer_city clean and file updated successfully.")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\810657689.py:1: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#  customer_city clean and file updated successfully.

# %% [markdown]
# ##Q5 is_prime_member, is_prime_eligible, is_festival_sale

# %%
df['is_festival_sale'].unique()
# Out:
# array([ True, False])

# %%
df = pd.read_csv(file_path)

# Define a universal boolean cleaner
def clean_boolean(value):
    try:
        value = str(value).strip().lower()
        if value in ['true', 'yes', 'y', '1']:
            return True
        elif value in ['false', 'no', 'n', '0']:
            return False
        else:
            return False  # or use pd.NA if you want to preserve missing
    except:
        return False

# Apply to all relevant columns
boolean_columns = ['is_prime_member', 'is_prime_eligible', 'is_festival_sale']
for col in boolean_columns:
    df[col] = df[col].apply(clean_boolean)
    
df['is_prime_member']=df['is_prime_member'].astype(bool)
df['is_prime_eligible']=df['is_prime_eligible'].astype(bool)
df['is_festival_sale']=df['is_festival_sale'].astype(bool)
# Save the cleaned data back to the same file
df.to_csv(file_path, index=False)

print(" Boolean columns standardized to True/False and file updated successfully.")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\2298127848.py:1: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#  Boolean columns standardized to True/False and file updated successfully.

# %%
df['is_prime_eligible'].unique()
# Out:
# array([ True, False])

# %% [markdown]
# ##Q6 categories

# %%
df['category'].unique()
# Out:
# <StringArray>
# ['Electronics']
# Length: 1, dtype: str

# %%
# Q6: Standardize product categories

df = pd.read_csv(file_path)

# Normalize category names
df['category'] = df['category'].str.lower().str.strip()

# Define mapping for standardization
category_map = {
    'electronics': 'Electronics',
    'electronic': 'Electronics',
    'electronics & accessories': 'Electronics',
    'electronicss': 'Electronics'
}

# Apply mapping
df['category'] = df['category'].replace(category_map)

# Capitalize standardized names
df['category'] = df['category'].str.title()

# Overwrite the original file with cleaned data
df.to_csv(file_path, index=False)

print(" Category names standardized and file updated successfully.")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\1881120276.py:3: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#  Category names standardized and file updated successfully.

# %% [markdown]
# ##Q7 delivery_days

# %%
df['delivery_days'].unique()
# Out:
# array([ 6,  4,  3,  5,  7,  0,  1,  2, 15])

# %%
df = pd.read_csv(file_path)

d_days={
   "Same Day":"0",
   "Express":"0",
    "1-2 days":"2",
    "-1":"1"
}

def clean_delivery_days(value):
    val = str(value).strip()
    return d_days.get(val, val)

df["delivery_days"] = df["delivery_days"].apply(clean_delivery_days)

df["delivery_days"]=df["delivery_days"].astype(int)


df.to_csv(file_path, index=False)

print(" delivery_days corrected and saved ")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\505917379.py:1: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#  delivery_days corrected and saved

# %%
df['delivery_days'].unique()
# Out:
# array([ 6,  4,  3,  5,  7,  0,  1,  2, 15])

# %% [markdown]
# ##Q8 customer_id', 'product_id', 'order_date', 'final_amount_inr

# %%
df[df.duplicated('product_id')].shape
# Out:
# (32836, 34)

# %%
# Q8: Flag duplicates
import pandas as pd

# Load your dataset

df = pd.read_csv(file_path)

df[df.duplicated(subset=['customer_id', 'product_id', 'order_date', 'final_amount_inr'], keep=False)]
df=df.drop_duplicates(subset=['customer_id', 'product_id', 'order_date', 'final_amount_inr'],keep='first')


# Overwrite original file with cleaned data
df.to_csv(file_path, index=False)

print("✅ Flag duplicates corrected and file updated successfully.")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\3095654537.py:6: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# ✅ Flag duplicates corrected and file updated successfully.

# %%
df[df.duplicated(subset=['customer_id', 'product_id', 'order_date', 'final_amount_inr'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [transaction_id, order_date, customer_id, product_id, product_name, category, subcategory, brand, original_price_inr, discount_percent, discounted_price_inr, quantity, subtotal_inr, delivery_charges, final_amount_inr, customer_city, customer_state, customer_tier, customer_spending_tier, customer_age_group, payment_method, delivery_days, delivery_type, is_prime_member, is_festival_sale, festival_name, customer_rating, return_status, order_month, order_year, order_quarter, product_weight_kg, is_prime_eligible, product_rating]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# ##Q9

# %%
df['original_price_inr'].unique()
# Out:
# array([123614.29  ,  54731.86  ,  97644.25  ,  21947.26  , 131194.65  ,
#         86987.64  ,  32169.01  ,  40264.16  ,  88664.85  ,  73967.02  ,
#         72564.1   ,   2098.7555,  45363.47  ,  23075.71  , 114096.63  ,
#         69584.33  ,  38884.19  ,  46234.09  ,  15065.01  , 164166.84  ,
#         64917.57  ,  29534.7   ,  86477.53  ,  13721.42  , 118141.16  ,
#         86591.57  ,  23264.31  ,  94029.64  ,  17206.23  ,  37013.54  ,
#        130430.24  , 130723.61  ,  41408.67  ,  56337.89  ,  75380.48  ,
#         23161.1   ,  46680.9   ,  43572.75  ,  19375.09  ,   3896.99  ,
#         20006.12  ,  30990.65  ,  96543.62  ,  22683.69  , 102649.14  ,
#        107387.37  ,  67444.91  ,  24762.02  ,  17790.72  ,  47979.    ,
#         24448.87  , 102741.22  ,  51356.92  ,  33199.84  ,   9753.11  ,
#         88872.68  ,  72369.63  , 126454.    ,  24762.    ,  78047.8   ,
#         60643.25  , 145589.8   ,  21212.    ,  40438.41  ,  12984.58  ,
# ...

# %%
import os
# Q9: Fix outlier prices


df = pd.read_csv(file_path)

# Normalize column names
df.columns = df.columns.str.strip().str.lower().str.replace('₹', '').str.replace(' ', '_')

# IQR bounds for fallback correction
Q1 = df['original_price_inr'].quantile(0.25)
Q3 = df['original_price_inr'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR

# Define expected price ranges by subcategory
subcategory_price_ranges = {
    'smartphones': (5000, 100000),
    'smart_watch': (500, 15000),
    'audio': (300, 20000),
    'tablets': (5000, 60000),
    'laptops': (20000, 150000),
    'tv_&_entertainment': (10000, 150000)
}

# Correction logic using subcategory
def correct_price(row):
    price = row['original_price_inr']
    subcat = str(row.get('subcategory', '')).strip().lower().replace(' ', '_')
    expected = subcategory_price_ranges.get(subcat)
    
    if expected:
        min_p, max_p = expected
        if price > max_p * 10:
            return price / 100
        elif price < min_p / 10:
            return price * 100
    if price > upper_bound:
        return price / 100
    return price

# Apply correction
df['original_price_inr'] = df.apply(correct_price, axis=1)

# Save updated file
df.to_csv(file_path, index=False)
print("✅ Outlier prices corrected and saved for amazon_india_2024.csv")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\3271668278.py:5: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# ✅ Outlier prices corrected and saved for amazon_india_2024.csv

# %% [markdown]
# ##10 payment_method

# %%
df['payment_method'].unique()
# Out:
# <StringArray>
# ['Cash on Delivery', 'Debit Card', 'Credit Card', 'Net Banking']
# Length: 4, dtype: str

# %%
import os
import pandas as pd
import numpy as np


df = pd.read_csv(file_path)

# Define mapping dictionary for payment methods
payment_mapping = {
    'upi': 'UPI',
    'phonepe': 'UPI',
    'googlepay': 'UPI',
    'bhim': 'UPI',

    'credit card': 'Credit Card',
    'creditcard': 'Credit Card',
    'cc': 'Credit Card',
    'visa': 'Credit Card',
    'mastercard': 'Credit Card',
    'BNPL' : 'Credit Card',

    'cash on delivery': 'Cash on Delivery',
    'cod': 'Cash on Delivery',
    'c.o.d': 'Cash on Delivery',
    'cash': 'Cash on Delivery',

    'debit card': 'Debit Card',
    'dc': 'Debit Card',
    'debitcard': 'Debit Card',

    'net banking': 'Net Banking',
    'netbanking': 'Net Banking',
    'nb': 'Net Banking',

    'emi': 'EMI',
    'installment': 'EMI',

    'wallet': 'Wallet',
    'paytm': 'Wallet',
    'amazonpay': 'Wallet',
    'mobikwik': 'Wallet'
}

# Function to clean payment method
def clean_payment_method(value):
    if pd.isna(value):
        return 'Unknown'
    value = str(value).lower().strip()
    # Check for exact key match first for a cleaner search in case of full strings
    if value in payment_mapping: 
        return payment_mapping[value]
    # Check for substring match (as in the original logic for cases like 'visa' in 'paid by visa cc')
    for key in payment_mapping:
        if key in value:
            return payment_mapping[key]
    return 'Other'

# Apply cleaning function
# Assuming the original column name is 'payment_method'
# If the column name is different, adjust 'payment_method' accordingly
df['payment_method'] = df['payment_method'].apply(clean_payment_method)

# Save the updated DataFrame back to the same file path string
df.to_csv(file_path, index=False)

print("✅ Payment method column cleaned and file updated successfully.")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\814702657.py:6: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# ✅ Payment method column cleaned and file updated successfully.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 33000 entries, 0 to 32999
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   transaction_id          33000 non-null  str
#  1   order_date              33000 non-null  str
#  2   customer_id             33000 non-null  str
#  3   product_id              33000 non-null  str
#  4   product_name            33000 non-null  str
#  5   category                33000 non-null  str
#  6   subcategory             33000 non-null  str
#  7   brand                   33000 non-null  str
#  8   original_price_inr      33000 non-null  float64
#  9   discount_percent        33000 non-null  float64
#  10  discounted_price_inr    33000 non-null  float64
#  11  quantity                33000 non-null  int64
#  12  subtotal_inr            33000 non-null  float64
#  13  delivery_charges        33000 non-null  int64
#  14  final_amount_inr        33000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id                0
# order_date                    0
# customer_id                   0
# product_id                    0
# product_name                  0
# category                      0
# subcategory                   0
# brand                         0
# original_price_inr            0
# discount_percent              0
# discounted_price_inr          0
# quantity                      0
# subtotal_inr                  0
# delivery_charges              0
# final_amount_inr              0
# customer_city               139
# customer_state                0
# customer_tier                 0
# customer_spending_tier        0
# customer_age_group            0
# payment_method                0
# delivery_days                 0
# delivery_type                 0
# is_prime_member               0
# is_festival_sale              0
# festival_name             22459
# customer_rating               0
# return_status                 0
# order_month                   0
# ...

# %%
df['delivery_charges'].unique()
# Out:
# array([0])

# %%
###ndelivery_charges null value remove

df = pd.read_csv(file_path)

# The correct way to replace the special NaN (Not a Number) value with 0
df['delivery_charges'] = df['delivery_charges'].fillna(0)
df['delivery_charges'] = df['delivery_charges'].astype(int)

df.to_csv(file_path, index=False)
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\3287117921.py:3: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df['delivery_charges'].unique()
# Out:
# array([0])

# %%
df['customer_age_group'].unique()
# Out:
# <StringArray>
# ['46-55', '26-35', '36-45', '18-25', 'unknown', '55+']
# Length: 6, dtype: str

# %%
df['customer_age_group']=df['customer_age_group'].fillna('unknown')
df.to_csv(file_path, index=False)

# %%
df['customer_city'].unique()
# Out:
# <StringArray>
# [       'Mumbai',     'Allahabad',       'Kolkata',      'Ludhiana',
#          'Delhi',       'Lucknow',        'Jaipur',   'Bhubaneswar',
#      'Ahmedabad',     'Bengaluru',          'Pune',         'Kochi',
#        'Chennai',        'Nagpur', 'Visakhapatnam',     'Gorakhpur',
#         'Kanpur',    'Chandigarh',     'Hyderabad',       'Aligarh',
#         'Indore',         'Patna',        'Meerut',    'Coimbatore',
#       'Vadodara',    'Saharanpur',             nan,     'Moradabad',
#          'Surat',      'Varanasi']
# Length: 30, dtype: str

# %%
df = pd.read_csv(file_path)

# The correct way to replace the special NaN (Not a Number) value with 0
df['customer_city'] = df['customer_city'].fillna('unknown')

df.to_csv(file_path, index=False)
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_25228\1464423568.py:1: DtypeWarning: Columns (0: festival_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#       transaction_id  order_date         customer_id   product_id  \
# 0  TXN_2015_00000001  2015-01-25  CUST_2015_00003884  PROD_000021
# 1  TXN_2015_00000002  2015-01-05  CUST_2015_00011709  PROD_000055
# 2  TXN_2015_00000003  2015-01-24  CUST_2015_00004782  PROD_000039
# 3  TXN_2015_00000004  2015-01-28  CUST_2015_00008105  PROD_000085
# 4  TXN_2015_00000005  2015-01-31  CUST_2015_00002955  PROD_000055
#
#                            product_name     category  subcategory     brand  \
# 0          Samsung Galaxy S6 16GB Black  Electronics  Smartphones   Samsung
# 1          OnePlus OnePlus 2 16GB White  Electronics  Smartphones   OnePlus
# 2      Samsung Galaxy Note 5 64GB Black  Electronics  Smartphones   Samsung
# 3  Motorola Moto G (3rd Gen) 16GB Black  Electronics  Smartphones  Motorola
# 4          OnePlus OnePlus 2 16GB White  Electronics  Smartphones   OnePlus
#
#    original_price_inr  discount_percent  ...  is_festival_sale  \
# ...

# %%
df['festival_name'].unique()
# Out:
# <StringArray>
# [           'Republic Day Sale',                            nan,
#                'Valentine Sale',                'Holi Festival',
#                   'Summer Sale',               'Back to School',
#                     'Prime Day', 'Amazon Great Indian Festival',
#                   'Diwali Sale']
# Length: 9, dtype: str

# %%
df['festival_name'] = df['festival_name'].str.replace('', '', regex=False)
#df.to_csv(file_path, index=False)

# %%
df['festival_name'].unique()
# Out:
# <StringArray>
# [           'Republic Day Sale',                            nan,
#                'Valentine Sale',                'Holi Festival',
#                   'Summer Sale',               'Back to School',
#                     'Prime Day', 'Amazon Great Indian Festival',
#                   'Diwali Sale']
# Length: 9, dtype: str

# %%
df['customer_rating'].unique()
# Out:
# array([5. , 4.5, 4. , 3. , 3.5])

# %%
df['customer_rating'].describe()
# Out:
# count    33000.000000
# mean         4.224788
# std          0.502216
# min          3.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.500000
# max          5.000000
# Name: customer_rating, dtype: float64

# %%
#df['customer_rating']=df['customer_rating'].fillna().mean
# Correct and concise one-line solution
#df['customer_rating'] = df['customer_rating'].fillna(df['customer_rating'].25%())

df['customer_rating'] = df['customer_rating'].fillna(df['customer_rating'].quantile(0.25))

df['customer_rating'] = df['customer_rating'].astype(float)

df.to_csv(file_path, index=False)

# %%
df['customer_rating'].unique()
# Out:
# array([5. , 4.5, 4. , 3. , 3.5])
